# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['mse','mae','friedman_mse'],'max_features':['auto','sqrt','log2'],'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=1)
# fitting the model for grid search
grid.fit(indep,dep)
# Out:
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] criterion=mse, max_features=auto, splitter=best .................
# [CV]  criterion=mse, max_features=auto, splitter=best, score=0.702, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=best .................
# [CV]  criterion=mse, max_features=auto, splitter=best, score=0.667, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=best .................
# [CV]  criterion=mse, max_features=auto, splitter=best, score=0.690, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=random ...............
# [CV]  criterion=mse, max_features=auto, splitter=random, score=0.646, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=random ...............
# [CV]  criterion=mse, max_features=auto, splitter=random, score=0.717, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=random ...............
# [CV]  criterion=mse, max_features=auto, splitter=random, score=0.668, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=best .................
# [CV]  criterion=mse, max_features=sqrt, splitter=best, score=0.644, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=best .................
# [CV]  criterion=mse, max_features=sqrt, splitter=best, score=0.700, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=best .................
# [CV]  criterion=mse, max_features=sqrt, splitter=best, score=0.473, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mse, max_features=sqrt, splitter=random, score=0.636, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mse, max_features=sqrt, splitter=random, score=0.593, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mse, max_features=sqrt, splitter=random, score=0.603, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=best .................
# [CV]  criterion=mse, max_features=log2, splitter=best, score=0.616, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=best .................
# [CV]  criterion=mse, max_features=log2, splitter=best, score=0.726, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=best .................
# [CV]  criterion=mse, max_features=log2, splitter=best, score=0.688, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=random ...............
# [CV]  criterion=mse, max_features=log2, splitter=random, score=0.670, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=random ...............
# [CV]  criterion=mse, max_features=log2, splitter=random, score=0.688, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=random ...............
# [CV]  criterion=mse, max_features=log2, splitter=random, score=0.643, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=best .................
# [CV]  criterion=mae, max_features=auto, splitter=best, score=0.695, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=best .................
# [CV]  criterion=mae, max_features=auto, splitter=best, score=0.732, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=best .................
# [CV]  criterion=mae, max_features=auto, splitter=best, score=0.674, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=random ...............
# [CV]  criterion=mae, max_features=auto, splitter=random, score=0.647, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=random ...............
# [CV]  criterion=mae, max_features=auto, splitter=random, score=0.762, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=random ...............
# [CV]  criterion=mae, max_features=auto, splitter=random, score=0.714, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=best .................
# [CV]  criterion=mae, max_features=sqrt, splitter=best, score=0.716, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=best .................
# [CV]  criterion=mae, max_features=sqrt, splitter=best, score=0.690, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=best .................
# [CV]  criterion=mae, max_features=sqrt, splitter=best, score=0.688, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mae, max_features=sqrt, splitter=random, score=0.596, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mae, max_features=sqrt, splitter=random, score=0.648, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mae, max_features=sqrt, splitter=random, score=0.689, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=best .................
# [CV]  criterion=mae, max_features=log2, splitter=best, score=0.739, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=best .................
# [CV]  criterion=mae, max_features=log2, splitter=best, score=0.408, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=best .................
# [CV]  criterion=mae, max_features=log2, splitter=best, score=0.589, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=random ...............
# [CV]  criterion=mae, max_features=log2, splitter=random, score=0.591, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=random ...............
# [CV]  criterion=mae, max_features=log2, splitter=random, score=0.644, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=random ...............
# [CV]  criterion=mae, max_features=log2, splitter=random, score=0.667, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=auto, splitter=best, score=0.706, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=auto, splitter=best, score=0.647, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=best ........
# [Parallel(n_jobs=1)]: Done  31 tasks      | elapsed:    0.4s
# [CV]  criterion=friedman_mse, max_features=auto, splitter=best, score=0.707, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=auto, splitter=random, score=0.688, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=auto, splitter=random, score=0.684, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=auto, splitter=random, score=0.717, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=best, score=0.743, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=best, score=0.662, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=best, score=0.642, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=random, score=0.626, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=random, score=0.593, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=random, score=0.618, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=log2, splitter=best, score=0.662, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=log2, splitter=best, score=0.647, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=log2, splitter=best, score=0.724, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=log2, splitter=random, score=0.645, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=log2, splitter=random, score=0.694, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=log2, splitter=random, score=0.679, total=   0.0s
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'mae', 'max_features': 'auto', 'splitter': 'random'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.010852      0.001579         0.003974        0.005620
# 1        0.006513      0.001467         0.000677        0.000958
# 2        0.000836      0.001182         0.006670        0.001299
# 3        0.005186      0.004095         0.000000        0.000000
# 4        0.005266      0.007447         0.003349        0.004736
# 5        0.003007      0.004252         0.001859        0.002629
# 6        0.036767      0.000472         0.005403        0.002798
# 7        0.028245      0.004101         0.001848        0.002613
# 8        0.017606      0.002467         0.006100        0.006915
# 9        0.017880      0.005702         0.001171        0.001656
# 10       0.026340      0.004127         0.000000        0.000000
# 11       0.015848      0.000018         0.003345        0.004731
# 12       0.005270      0.004190         0.002086        0.002951
# 13       0.008426      0.000316         0.001082        0.000832
# 14       0.004714      0.003333         0.002727        0.003856
# 15       0.002707      0.003829         0.005180        0.005954
# 16       0.006540      0.001004         0.002518        0.001956
# 17       0.005436      0.003846         0.002738        0.002502
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.702033
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.646256
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.644310
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.636181
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.616358
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.670342
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.694748
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.646607
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.716286
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.596066
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.739238
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.590683
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.706461
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.688380
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.742586
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.626393
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.661545
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.644869
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.666733           0.689503         0.686090        0.014612
# 1            0.717153           0.667670         0.677026        0.029690
# 2            0.699791           0.473111         0.605738        0.096478
# 3            0.592801           0.603134         0.610705        0.018501
# 4            0.725975           0.687569         0.676634        0.045414
# 5            0.688472           0.643303         0.667372        0.018559
# 6            0.731782           0.674013         0.700181        0.023895
# 7            0.762119           0.714283         0.707670        0.047389
# 8            0.690240           0.687802         0.698109        0.012891
# 9            0.648348           0.689418         0.644611        0.038203
# 10           0.408280           0.589251         0.578923        0.135310
# 11           0.644043           0.667069         0.633932        0.031994
# 12           0.647136           0.706526         0.686707        0.027982
# 13           0.684090           0.717310         0.696593        0.014753
# 14           0.662374           0.641691         0.682217        0.043515
# 15           0.592802           0.617872         0.612356        0.014258
# 16           0.647150           0.724201         0.677632        0.033450
# 17           0.694119           0.679464         0.672817        0.020648
#
#     rank_test_score
# 0                 6
# 1                 9
# 2                17
# 3                16
# 4                10
# 5                12
# 6                 2
# 7                 1
# 8                 3
# 9                13
# 10               18
# 11               14
# 12                5
# 13                4
# 14                7
# 15               15
# 16                8
# 17               11

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# BMI:43
# Children:2
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[4673.3922]
