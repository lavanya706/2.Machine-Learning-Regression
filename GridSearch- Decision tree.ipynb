# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['mse','mae','friedman_mse'],'max_features':['auto','sqrt','log2'],'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# C:\Users\lavanya\anaconda3\envs\aiml\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] criterion=mse, max_features=auto, splitter=best .................
# [CV]  criterion=mse, max_features=auto, splitter=best, score=0.520, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=best .................
# [CV]  criterion=mse, max_features=auto, splitter=best, score=0.693, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=best .................
# [CV]  criterion=mse, max_features=auto, splitter=best, score=0.703, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=random ...............
# [CV]  criterion=mse, max_features=auto, splitter=random, score=0.515, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=random ...............
# [CV]  criterion=mse, max_features=auto, splitter=random, score=0.606, total=   0.0s
# [CV] criterion=mse, max_features=auto, splitter=random ...............
# [CV]  criterion=mse, max_features=auto, splitter=random, score=0.652, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=best .................
# [CV]  criterion=mse, max_features=sqrt, splitter=best, score=0.598, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=best .................
# [CV]  criterion=mse, max_features=sqrt, splitter=best, score=0.435, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=best .................
# [CV]  criterion=mse, max_features=sqrt, splitter=best, score=0.697, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mse, max_features=sqrt, splitter=random, score=0.603, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mse, max_features=sqrt, splitter=random, score=0.555, total=   0.0s
# [CV] criterion=mse, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mse, max_features=sqrt, splitter=random, score=0.598, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=best .................
# [CV]  criterion=mse, max_features=log2, splitter=best, score=0.617, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=best .................
# [CV]  criterion=mse, max_features=log2, splitter=best, score=0.590, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=best .................
# [CV]  criterion=mse, max_features=log2, splitter=best, score=0.620, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=random ...............
# [CV]  criterion=mse, max_features=log2, splitter=random, score=0.588, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=random ...............
# [CV]  criterion=mse, max_features=log2, splitter=random, score=0.570, total=   0.0s
# [CV] criterion=mse, max_features=log2, splitter=random ...............
# [CV]  criterion=mse, max_features=log2, splitter=random, score=0.598, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=best .................
# [CV]  criterion=mae, max_features=auto, splitter=best, score=0.670, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=best .................
# [CV]  criterion=mae, max_features=auto, splitter=best, score=0.644, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=best .................
# [CV]  criterion=mae, max_features=auto, splitter=best, score=0.697, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=random ...............
# [CV]  criterion=mae, max_features=auto, splitter=random, score=0.679, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=random ...............
# [CV]  criterion=mae, max_features=auto, splitter=random, score=0.663, total=   0.0s
# [CV] criterion=mae, max_features=auto, splitter=random ...............
# [CV]  criterion=mae, max_features=auto, splitter=random, score=0.713, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=best .................
# [CV]  criterion=mae, max_features=sqrt, splitter=best, score=0.627, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=best .................
# [CV]  criterion=mae, max_features=sqrt, splitter=best, score=0.687, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=best .................
# [CV]  criterion=mae, max_features=sqrt, splitter=best, score=0.666, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mae, max_features=sqrt, splitter=random, score=0.543, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mae, max_features=sqrt, splitter=random, score=0.538, total=   0.0s
# [CV] criterion=mae, max_features=sqrt, splitter=random ...............
# [CV]  criterion=mae, max_features=sqrt, splitter=random, score=0.555, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=best .................
# [CV]  criterion=mae, max_features=log2, splitter=best, score=0.577, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=best .................
# [CV]  criterion=mae, max_features=log2, splitter=best, score=0.607, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=best .................
# [CV]  criterion=mae, max_features=log2, splitter=best, score=0.569, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=random ...............
# [CV]  criterion=mae, max_features=log2, splitter=random, score=0.643, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=random ...............
# [CV]  criterion=mae, max_features=log2, splitter=random, score=0.587, total=   0.0s
# [CV] criterion=mae, max_features=log2, splitter=random ...............
# [CV]  criterion=mae, max_features=log2, splitter=random, score=0.571, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=auto, splitter=best, score=0.563, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=auto, splitter=best, score=0.670, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=auto, splitter=best, score=0.687, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=auto, splitter=random, score=0.618, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=auto, splitter=random, score=0.696, total=   0.0s
# [CV] criterion=friedman_mse, max_features=auto, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=auto, splitter=random, score=0.678, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=best, score=0.448, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=best, score=0.624, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=best, score=0.423, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=random, score=0.642, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=random, score=0.503, total=   0.0s
# [CV] criterion=friedman_mse, max_features=sqrt, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=sqrt, splitter=random, score=0.650, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=log2, splitter=best, score=0.456, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=log2, splitter=best, score=0.606, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=best ........
# [CV]  criterion=friedman_mse, max_features=log2, splitter=best, score=0.683, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=log2, splitter=random, score=0.480, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=log2, splitter=random, score=0.517, total=   0.0s
# [CV] criterion=friedman_mse, max_features=log2, splitter=random ......
# [CV]  criterion=friedman_mse, max_features=log2, splitter=random, score=0.644, total=   0.0s
# [Parallel(n_jobs=1)]: Done  31 tasks      | elapsed:    0.2s
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
re=grid.cv_results_
grid_prediction= grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_prediction)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'mae', 'max_features': 'auto', 'splitter': 'random'}: 0.7333776873770378

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.001840      0.002602         0.000000        0.000000
# 1        0.000000      0.000000         0.000000        0.000000
# 2        0.000000      0.000000         0.000000        0.000000
# 3        0.000000      0.000000         0.001840        0.002602
# 4        0.001676      0.002371         0.000000        0.000000
# 5        0.000000      0.000000         0.000000        0.000000
# 6        0.015661      0.000160         0.000000        0.000000
# 7        0.013989      0.008744         0.003344        0.004729
# 8        0.012539      0.002487         0.000000        0.000000
# 9        0.018322      0.002133         0.000287        0.000406
# 10       0.013108      0.002053         0.000000        0.000000
# 11       0.006863      0.005182         0.001541        0.002179
# 12       0.003188      0.004509         0.000000        0.000000
# 13       0.004019      0.003091         0.000335        0.000474
# 14       0.000000      0.000000         0.003350        0.004738
# 15       0.001680      0.002376         0.000000        0.000000
# 16       0.000000      0.000000         0.000000        0.000000
# 17       0.000000      0.000000         0.005780        0.008175
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.519651
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.514761
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.598027
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.603189
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.617452
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.588106
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.670422
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.679007
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.626756
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.543319
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.577484
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.642796
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.563475
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.617765
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.447829
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.641674
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.456351
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.480310
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.692501           0.702516         0.638090        0.083989
# 1            0.605557           0.652254         0.590772        0.057110
# 2            0.434658           0.696621         0.576459        0.107972
# 3            0.555263           0.598190         0.585567        0.021507
# 4            0.590469           0.620286         0.609411        0.013433
# 5            0.569763           0.598360         0.585413        0.011823
# 6            0.644482           0.697366         0.670756        0.021579
# 7            0.662509           0.713434         0.684977        0.021204
# 8            0.687020           0.665914         0.659860        0.024979
# 9            0.538455           0.555437         0.545734        0.007137
# 10           0.607102           0.569215         0.584592        0.016258
# 11           0.586677           0.570541         0.600052        0.030983
# 12           0.669562           0.686741         0.639840        0.054541
# 13           0.696032           0.677720         0.663787        0.033443
# 14           0.624093           0.423392         0.498381        0.089376
# 15           0.502671           0.649610         0.598034        0.067453
# 16           0.606237           0.683254         0.581806        0.094252
# 17           0.517344           0.643728         0.547053        0.069957
#
#     rank_test_score
# 0                 6
# 1                10
# 2                15
# 3                11
# 4                 7
# 5                12
# 6                 2
# 7                 1
# 8                 4
# 9                17
# 10               13
# 11                8
# 12                5
# 13                3
# 14               18
# 15                9
# 16               14
# 17               16

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# BMI:43
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#␣change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[14988.432]
